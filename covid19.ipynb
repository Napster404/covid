# %% [markdown]
# **IMPORTING LIBRARIES**

# %%
import torch
import numpy as np
import pandas as pd
from torchvision import datasets
from torchvision.transforms import transforms
from torch.utils.data.sampler import SubsetRandomSampler
import matplotlib.pyplot as plt
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %% [markdown]
# **Check if GPU is available**
#
# check you gpu compatibility here https://developer.nvidia.com/cuda-gpus#compute

# %%
gpu = torch.cuda.is_available()

# %% [markdown]
# **Loading the data**
#
# get dataset here https://drive.google.com/drive/folders/1cbNOjC0EVHxrQVgMrVVaQKR7c2TB3376?usp=sharing

# %%
num_workers = 0

batch_size = 15
valid_size = 0.2

transform = transforms.Compose([
    transforms.Resize((224,224)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])

train_image_path = "/content/drive/My Drive/dataset/train"
test_image_path = "/content/drive/My Drive/dataset/test"

train_dataset = datasets.ImageFolder(train_image_path, transform=transform)

test_dataset = datasets.ImageFolder(test_image_path , transform = transform)

# %% [markdown]
# **Test sampler**

# %%
num_test = len(test_dataset)
indices_test = list(range(num_test))
np.random.shuffle(indices_test)
test_idx = indices_test
test_sampler = SubsetRandomSampler(indices_test)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, 
                                            sampler=test_sampler , num_workers=num_workers)

# %% [markdown]
# **Data Loaders**

# %%
num_train = len(train_dataset)
#print(num_train)
indices = list(range(num_train))
np.random.shuffle(indices)
split = int(np.floor(valid_size * num_train))
train_idx, valid_idx = indices[split:], indices[:split]

# define samplers for obtaining training and validation batches
train_sampler = SubsetRandomSampler(train_idx)
valid_sampler = SubsetRandomSampler(valid_idx)

# prepare data loaders (combine dataset and sampler)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size,
    sampler=train_sampler, num_workers=num_workers)
valid_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, 
    sampler=valid_sampler, num_workers=num_workers)

classes = [0,1]

# %% [markdown]
# Function to show image

# %%
def imshow(img):
    img = img / 2 + 0.5  # unnormalize
    plt.imshow(np.transpose(img, (1, 2, 0)),cmap='Accent')

# %% [markdown]
# Show a batch of images

# %%
# obtain one batch of training images
dataiter = iter(train_loader)
images, labels = dataiter.next()
images = images.numpy() # convert images to numpy for display

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(25, 4))
# display 1 batch
covid = ['Covid+','Covid-']
for idx in np.arange(batch_size):
    ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])
    ax.set_title(covid[labels[idx]])

# %% [markdown]
# **Defining model architecture for CNN**

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3,32,3,padding =1)
        self.conv2 = nn.Conv2d(32,64,3,padding =1)
        self.pool = nn.MaxPool2d(2,2)
        self.drop1 = nn.Dropout(p=0.25,inplace = True)
        self.drop2 = nn.Dropout(p=0.5,inplace = True)
        self.conv3 = nn.Conv2d(64,64,3,padding=1)
        self.conv4 = nn.Conv2d(64,128,3,padding=1)
        self.fc1 = nn.Linear(28*28*128,64)
        self.fc2 = nn.Linear(64,2)
        self.softmax = nn.LogSoftmax(dim=1)
    def forward(self,x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = self.pool(x)
        x = self.drop1(x)
        x = F.relu(self.conv3(x))
        x = self.pool(x)
        x = self.drop1(x)
        x = F.relu(self.conv4(x))
        x = self.pool(x)
        x = self.drop1(x)
        x = x.view(-1,28*28*128)
        x = F.relu(self.fc1(x))
        x = self.drop2(x)
        x = self.softmax(self.fc2(x))
        return x

# create a complete CNN
model = Net()
print(model)

# move tensors to GPU if CUDA is available
if gpu:
    model.cuda()
# Out:
# Net(
#   (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (drop1): Dropout(p=0.25, inplace=True)
#   (drop2): Dropout(p=0.5, inplace=True)
#   (conv3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv4): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (fc1): Linear(in_features=100352, out_features=64, bias=True)
#   (fc2): Linear(in_features=64, out_features=2, bias=True)
#   (softmax): LogSoftmax()
# )

# %% [markdown]
# Using cross entropy loss function
# and Adam optimizer

# %%
criterion  = nn.CrossEntropyLoss(weight=None,size_average=True)
optimizer  = optim.Adam(model.parameters() , lr=0.003)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:43: UserWarning: size_average and reduce args will be deprecated, please use reduction='mean' instead.
#   warnings.warn(warning.format(ret))

# %% [markdown]
# Training model

# %%
total_epochs = 40
min_loss = 1e18

for epochs in range(0,total_epochs):
    torch.cuda.empty_cache()
    t_loss= 0.0
    v_loss= 0.0
    
    model.train()
    
    for data,target in train_loader:
        if gpu:
            data = data.cuda()
            target = target.cuda()
        
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output,target)
        
        loss.backward()
        optimizer.step()
        t_loss += loss.item()*data.size(0)

    model.eval()
    for data,target in valid_loader:
        if gpu:
            data = data.cuda()
            target = target.cuda()
        
      #  optimizer.zero_grad()
        output = model(data)
        loss = criterion(output,target)
      #  loss.backward()
      #  optimizer.step()
        v_loss += loss.item()*data.size(0)
    
    t_loss/= len(train_loader.sampler)
    v_loss/= len(valid_loader.sampler)
    print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
        epochs, t_loss, v_loss))
    
    if v_loss <= min_loss:
        print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
        min_loss,
        v_loss))
        torch.save(model.state_dict(), 'cur_model.pt')
        min_loss = v_loss
# Out:
# Epoch: 0 	Training Loss: 0.907391 	Validation Loss: 0.372668
# Validation loss decreased (1000000000000000000.000000 --> 0.372668).  Saving model ...
# Epoch: 1 	Training Loss: 0.219539 	Validation Loss: 0.263542
# Validation loss decreased (0.372668 --> 0.263542).  Saving model ...
# Epoch: 2 	Training Loss: 0.155343 	Validation Loss: 0.213237
# Validation loss decreased (0.263542 --> 0.213237).  Saving model ...
# Epoch: 3 	Training Loss: 0.183517 	Validation Loss: 0.188398
# Validation loss decreased (0.213237 --> 0.188398).  Saving model ...
# Epoch: 4 	Training Loss: 0.154323 	Validation Loss: 0.218823
# Epoch: 5 	Training Loss: 0.117548 	Validation Loss: 0.160421
# Validation loss decreased (0.188398 --> 0.160421).  Saving model ...
# Epoch: 6 	Training Loss: 0.076014 	Validation Loss: 0.153140
# Validation loss decreased (0.160421 --> 0.153140).  Saving model ...
# Epoch: 7 	Training Loss: 0.093788 	Validation Loss: 0.142729
# Validation loss decreased (0.153140 --> 0.142729).  Saving model ...
# Epoch: 8 	Training Loss: 0.098705 	Validation Loss: 0.198793
# Epoch: 9 	Training Loss: 0.159912 	Validation Loss: 0.204457
# Epoch: 10 	Training Loss: 0.107481 	Validation Loss: 0.216068
# Epoch: 11 	Training Loss: 0.085148 	Validation Loss: 0.202426
# Epoch: 12 	Training Loss: 0.055976 	Validation Loss: 0.114525
# Validation loss decreased (0.142729 --> 0.114525).  Saving model ...
# Epoch: 13 	Training Loss: 0.055939 	Validation Loss: 0.163471
# Epoch: 14 	Training Loss: 0.084271 	Validation Loss: 0.102063
# Validation loss decreased (0.114525 --> 0.102063).  Saving model ...
# Epoch: 15 	Training Loss: 0.064007 	Validation Loss: 0.122903
# Epoch: 16 	Training Loss: 0.085669 	Validation Loss: 0.190553
# Epoch: 17 	Training Loss: 0.094955 	Validation Loss: 0.188669
# Epoch: 18 	Training Loss: 0.062702 	Validation Loss: 0.119797
# Epoch: 19 	Training Loss: 0.059832 	Validation Loss: 0.340685
# Epoch: 20 	Training Loss: 0.102662 	Validation Loss: 0.099875
# Validation loss decreased (0.102063 --> 0.099875).  Saving model ...
# Epoch: 21 	Training Loss: 0.106157 	Validation Loss: 0.150159
# Epoch: 22 	Training Loss: 0.084662 	Validation Loss: 0.120442
# Epoch: 23 	Training Loss: 0.102991 	Validation Loss: 0.278240
# Epoch: 24 	Training Loss: 0.064670 	Validation Loss: 0.145074
# Epoch: 25 	Training Loss: 0.073267 	Validation Loss: 0.116276
# Epoch: 26 	Training Loss: 0.062932 	Validation Loss: 0.129544
# Epoch: 27 	Training Loss: 0.041262 	Validation Loss: 0.354189
# Epoch: 28 	Training Loss: 0.108925 	Validation Loss: 0.094309
# Validation loss decreased (0.099875 --> 0.094309).  Saving model ...
# Epoch: 29 	Training Loss: 0.072210 	Validation Loss: 0.139785
# Epoch: 30 	Training Loss: 0.041569 	Validation Loss: 0.101524
# Epoch: 31 	Training Loss: 0.040056 	Validation Loss: 0.094290
# Validation loss decreased (0.094309 --> 0.094290).  Saving model ...
# Epoch: 32 	Training Loss: 0.035827 	Validation Loss: 0.149369
# Epoch: 33 	Training Loss: 0.068506 	Validation Loss: 0.103177
# Epoch: 34 	Training Loss: 0.078962 	Validation Loss: 0.076887
# Validation loss decreased (0.094290 --> 0.076887).  Saving model ...
# Epoch: 35 	Training Loss: 0.070072 	Validation Loss: 0.087912
# Epoch: 36 	Training Loss: 0.027020 	Validation Loss: 0.152734
# Epoch: 37 	Training Loss: 0.067469 	Validation Loss: 0.381184
# Epoch: 38 	Training Loss: 0.061168 	Validation Loss: 0.196591
# Epoch: 39 	Training Loss: 0.070760 	Validation Loss: 0.182284

# %% [markdown]
# Loading our saved model

# %%
torch.cuda.empty_cache()
model.load_state_dict(torch.load('cur_model.pt'))
if gpu:
    model = model.cuda()
model
# Out:
# Net(
#   (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (drop1): Dropout(p=0.25, inplace=True)
#   (drop2): Dropout(p=0.5, inplace=True)
#   (conv3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv4): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (fc1): Linear(in_features=100352, out_features=64, bias=True)
#   (fc2): Linear(in_features=64, out_features=2, bias=True)
#   (softmax): LogSoftmax()
# )

# %% [markdown]
# Testing our model

# %%
test_loss = 0.0
class_correct = list(0.0 for i in range(2) )
class_total = list(0.0 for i in range(2))

model.eval()

for data,target in test_loader:
    if gpu:
        data = data.cuda()
        target = target.cuda()
    
    output = model(data)
    loss = criterion(output,target)
    test_loss+= loss.item()*data.size(0)
    
    _ , pred = torch.max(output,dim=1)
    correct_tensor = pred.eq(target.data.view_as(pred))
    correct = np.squeeze(correct_tensor.numpy()) if not gpu else np.squeeze(correct_tensor.cpu().numpy())
    for i in range(target.shape[0]):
        label = target.data[i]
        class_correct[label] += correct[i].item()
        class_total[label] += 1

test_loss = test_loss/len(test_loader.dataset)
print('Test Loss: {:.6f}\n'.format(test_loss))

for i in range(2):
    if class_total[i] > 0:
        print('Test Accuracy of %5s: %2d%% (%2d/%2d)' % (
            classes[i], 100 * class_correct[i] / class_total[i],
            np.sum(class_correct[i]), np.sum(class_total[i])))
    else:
        print('Test Accuracy of %5s: N/A (no training examples)' % (classes[i]))

    
print('\nTest Accuracy (Overall): %2d%% (%2d/%2d)' % (
    100. * np.sum(class_correct) / np.sum(class_total),
    np.sum(class_correct), np.sum(class_total)))
# Out:
# Test Loss: 0.212454
#
# Test Accuracy of     0: 96% (49/51)
# Test Accuracy of     1: 98% (50/51)
#
# Test Accuracy (Overall): 97% (99/102)
